# %%
import pandas as pd
import matplotlib
import re

# %%
data = pd.read_csv('train.csv/train.csv')
data
# Out:
#       AnimalID        Name             DateTime      OutcomeType  \
# 0      A671945     Hambone  2014-02-12 18:22:00  Return_to_owner
# 1      A656520       Emily  2013-10-13 12:44:00       Euthanasia
# 2      A686464      Pearce  2015-01-31 12:28:00         Adoption
# 3      A683430         NaN  2014-07-11 19:09:00         Transfer
# 4      A667013         NaN  2013-11-15 12:52:00         Transfer
# 5      A677334        Elsa  2014-04-25 13:04:00         Transfer
# 6      A699218       Jimmy  2015-03-28 13:11:00         Transfer
# 7      A701489         NaN  2015-04-30 17:02:00         Transfer
# 8      A671784        Lucy  2014-02-04 17:17:00         Adoption
# 9      A677747         NaN  2014-05-03 07:48:00         Adoption
# 10     A668402         NaN  2013-12-05 15:50:00         Transfer
# 11     A666320         NaN  2013-11-04 14:48:00         Adoption
# 12     A684601      Rocket  2016-02-03 11:27:00         Adoption
# ...

# %%
# Start cleaning the data 
# 1. AnimalId is probably not needed drop the column
# 2. Also it feels that OutcomeSubtype is kind of sub category of OutcomeType so I would want to drop it
data = data.drop(['AnimalID','OutcomeSubtype'], axis = 1)

# %%
# check for nan values in all the columns and tackle them one by one
data.isna().sum()
# Out:
# Name              7691
# DateTime             0
# OutcomeType          0
# AnimalType           0
# SexuponOutcome       1
# AgeuponOutcome      18
# Breed                0
# Color                0
# dtype: int64

# %%
# Remove the Name column and refactor it. If name exists label it as '1' and if there is no name then label it '0'
data['Name'] = data[['Name']].fillna(value=0)

# %%
data['newName'] = (data['Name'] != 0).astype('int64')

# %%
data = data.drop(['Name'], axis = 1)

# %%
# Check for null values now 
data.isna().sum()
# Out:
# DateTime           0
# OutcomeType        0
# AnimalType         0
# SexuponOutcome     1
# AgeuponOutcome    18
# Breed              0
# Color              0
# newName            0
# dtype: int64

# %%
# As AnimalType contains only two types of class like dog and cat making use of get dummies (aka. one hot encoding) helps
data = pd.get_dummies(data,columns=['AnimalType'])

# %%
# Now try to change theh color feature
data['Color'] = data['Color'].apply(lambda x: 1 if '/' in x else 0)

# %%
# Try to change the breed column in a meaningful way
data['breed_type'] = data.Breed.str.extract(pat='({})'.format('|'.join(['Mix'])),flags=re.IGNORECASE,expand=False).str.lower().fillna('pure')

# %%
data.iloc[2480,:]
# Out:
# DateTime          2016-02-16 10:17:00
# OutcomeType                  Transfer
# SexuponOutcome            Intact Male
# AgeuponOutcome                      0
# Color                               1
# newName                             0
# AnimalType_Cat                      1
# AnimalType_Dog                      0
# breed_type                        mix
# Name: 2480, dtype: object

# %%
data = data.drop(['Breed'], axis = 1)

# %%
data['AgeuponOutcome'] = data[['AgeuponOutcome']].fillna(value='0 years')

# %%
# Change AgeuponOutcome to numeric as well 
def age_converter(row):
    str_age = row['AgeuponOutcome']
    age = str_age.split(" ").str.get(0)
    unit = unit.lower()
    if "day" in unit:
        if age == '0':
            return 1
        return int(age)
    if "week" in unit:
        if age == '0':
            return 7
        return int(age) * 7
    if "month" in unit:
        if age == '0':
            return 30
        return int(age) * 4 * 28
    if "year" in unit:
        if age == '0':
            return 365
        return int(age) * 28 * 12
    
data['numeric_age'] = data.apply(age_converter, axis = 1)
data = data.drop('AgeuponOutcome', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a80cd56e9d37> in <module>()
#      21         return int(age) * 28 * 12
#      22
# ---> 23 data['numeric_age'] = data.apply(age_converter, axis = 1)
#      24 data = data.drop('AgeuponOutcome', axis = 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ...

# %%
str_age = data['AgeuponOutcome']
age = str_age.str.split(" ").str.get(1)

# %%
age.dtype
# Out:
# dtype('O')

# %%
data['OutcomeType'].value_counts().plot.bar()
